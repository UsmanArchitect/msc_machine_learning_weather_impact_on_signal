# %%
import pandas as pd

# %%
# Define the path to your directory containing Excel files
# You can use a wildcard '*' to match all Excel files (.xlsx or .xls): 
# 
csv_files_path = "C:/Users/ukhan/Documents/DataSet/OpenMesh/nceia_noaa/"

# %%
# Define the path to your directory containing Excel files
# You can use a wildcard '*' to match all Excel files (.xlsx or .xls): 
# 
open_mesh_path = "C:/Users/ukhan/Documents/DataSet/OpenMesh/"

# %% [markdown]
# ### Merge Open Mesh data with weather data

# %%
weather_data = pd.read_csv(csv_files_path+'2023_2024_lat_40_6__40_8__lon_-74_01__-73_92_nyc_44K_chkpoint2.csv')

# %%
weather_data = pd.read_csv(csv_files_path+'2023_2024_lat_40_6__40_8__lon_-74_01__-73_92_nyc_44K_chkpoint2_22cols.csv')

# %%
weather_data.shape
# Out:
# (11448, 19)

# %%
open_mesh_data = pd.read_csv(open_mesh_path+"wireless_data_merged_nearest_coord_1.csv")

# %%
open_mesh_data.columns
# Out:
# Index(['Datetime', 'sublink_id', 'rsl_value', 'frequency', 'length', 'rsl',
#        'nr_site_0_lat', 'nr_site_0_lon'],
#       dtype='object')

# %%
open_mesh_data.shape
# Out:
# (32452469, 8)

# %%
open_mesh_data.head()
# Out:
#               Datetime  sublink_id  rsl_value  frequency  length   rsl  \
# 0  2023-10-29 00:00:00           1      -65.0      62640   623.0 -60.0
# 1  2023-10-29 00:01:00           1      -65.0      62640   623.0 -60.0
# 2  2023-10-29 00:02:00           1      -65.0      62640   623.0 -60.0
# 3  2023-10-29 00:03:00           1      -65.0      62640   623.0 -60.0
# 4  2023-10-29 00:04:00           1      -65.0      62640   623.0 -60.0
#
#    nr_site_0_lat  nr_site_0_lon
# 0       40.77898      -73.96925
# 1       40.77898      -73.96925
# 2       40.77898      -73.96925
# 3       40.77898      -73.96925
# 4       40.77898      -73.96925

# %%
open_mesh_data['Datetime'] = pd.to_datetime(open_mesh_data.Datetime)

# %%
open_mesh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32452469 entries, 0 to 32452468
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Datetime       datetime64[ns]
#  1   sublink_id     int64
#  2   rsl_value      float64
#  3   frequency      int64
#  4   length         float64
#  5   rsl            float64
#  6   nr_site_0_lat  float64
#  7   nr_site_0_lon  float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 1.9 GB

# %%
weather_data.head()
# Out:
#                   DATE   LATITUDE  LONGITUDE  ELEVATION  WND_SPEED_MPS  \
# 0  2023-10-29 00:56:00  40.701214 -74.009028       2.13              0
# 1  2023-10-29 01:56:00  40.701214 -74.009028       2.13             21
# 2  2023-10-29 02:56:00  40.701214 -74.009028       2.13              0
# 3  2023-10-29 03:56:00  40.701214 -74.009028       2.13             26
# 4  2023-10-29 04:56:00  40.701214 -74.009028       2.13             21
#
#    WND_TYPE_CODE_N  WND_TYPE_CODE_V  CIG_AGL  VIS_DISTANCE_MTS  TMP_C  \
# 0                0                0     1829             16093    228
# 1                0                1    22000             16093    211
# 2                0                0    22000             16093    200
# 3                1                0    22000             16093    189
# 4                0                1     2438             16093    178
#
#    DEW_TMP_C  SLP_HECTOPASCALS  GD1_HEIGHT_MTS  GD1__1  GD1__2  GD1__3  \
# ...

# %%
weather_data.DATE = pd.to_datetime(weather_data.DATE)

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11448 entries, 0 to 11447
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DATE                       11448 non-null  datetime64[ns]
#  1   LATITUDE                   11448 non-null  float64
#  2   LONGITUDE                  11448 non-null  float64
#  3   ELEVATION                  11448 non-null  float64
#  4   WND_SPEED_MPS              11448 non-null  int64
#  5   WND_TYPE_CODE_N            11448 non-null  int64
#  6   WND_TYPE_CODE_V            11448 non-null  int64
#  7   CIG_AGL                    11448 non-null  int64
#  8   VIS_DISTANCE_MTS           11448 non-null  int64
#  9   TMP_C                      11448 non-null  int64
#  10  DEW_TMP_C                  11448 non-null  int64
#  11  SLP_HECTOPASCALS           11448 non-null  int64
#  12  GD1_HEIGHT_MTS             8705 non-null   float64
# ...

# %%
open_mesh_data.columns
# Out:
# Index(['Datetime', 'sublink_id', 'rsl_value', 'frequency', 'length', 'rsl',
#        'nr_site_0_lat', 'nr_site_0_lon'],
#       dtype='object')

# %%
weather_data.columns
# Out:
# Index(['DATE', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'WND_SPEED_MPS',
#        'WND_TYPE_CODE_N', 'WND_TYPE_CODE_V', 'CIG_AGL', 'VIS_DISTANCE_MTS',
#        'TMP_C', 'DEW_TMP_C', 'SLP_HECTOPASCALS', 'GD1_HEIGHT_MTS', 'GD1__1',
#        'GD1__2', 'GD1__3', 'GD1__4', 'GD1__5', 'MA1_ALTIMETER_HECTOPASCAL'],
#       dtype='object')

# %% [markdown]
# ### Merge weather data and wireless data on DATE and lat column

# %% [markdown]
# * Inner Join to drop columns for which match is not found

# %%
wireless_weather_data_df = pd.merge(open_mesh_data, weather_data, left_on=['Datetime', 'nr_site_0_lat'], right_on=['DATE', 'LATITUDE'], how='inner')

# %%
wireless_weather_data_df.shape
# Out:
# (581376, 27)

# %%
weather_data.shape
# Out:
# (11448, 19)

# %%
open_mesh_data.shape
# Out:
# (32452469, 8)

# %%
wireless_weather_data_df.to_csv(open_mesh_path+"wireless_weather_data_638K.csv", index=False)

# %%
wireless_weather_data_df.head()
# Out:
#              Datetime  sublink_id  rsl_value  frequency  length   rsl  \
# 0 2023-10-29 00:51:00           1      -65.0      62640   623.0 -60.0
# 1 2023-10-29 00:51:00           2      -59.0      60480   222.1 -62.0
# 2 2023-10-29 00:51:00           3      -61.0      62640   623.0 -60.0
# 3 2023-10-29 00:51:00           4      -56.0      58320   451.8 -57.0
# 4 2023-10-29 00:51:00           5      -58.0      60480   222.1 -57.0
#
#    nr_site_0_lat  nr_site_0_lon                DATE  LATITUDE  ...  TMP_C  \
# 0       40.77898      -73.96925 2023-10-29 00:51:00  40.77898  ...    222
# 1       40.77898      -73.96925 2023-10-29 00:51:00  40.77898  ...    222
# 2       40.77898      -73.96925 2023-10-29 00:51:00  40.77898  ...    222
# 3       40.77898      -73.96925 2023-10-29 00:51:00  40.77898  ...    222
# 4       40.77898      -73.96925 2023-10-29 00:51:00  40.77898  ...    222
#
#    DEW_TMP_C  SLP_HECTOPASCALS  GD1_HEIGHT_MTS  GD1__1  GD1__2  GD1__3  \
# ...
