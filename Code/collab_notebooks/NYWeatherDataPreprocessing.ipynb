# %% [markdown]
# # Data Preprocessing for Weather Data

# %%
def mount_gdrive():
  from google.colab import drive
  drive.mount('/content/drive')

# %% [markdown]
# ## Import Libraries required

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## New York Weather Data 2016-2022 (aadimator/nyc-weather-2016-to-2022)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("aadimator/nyc-weather-2016-to-2022")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 732k/732k [00:00<00:00, 84.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/aadimator/nyc-weather-2016-to-2022/versions/1

# %%
# !ls /root/.cache/kagglehub/datasets/aadimator/nyc-weather-2016-to-2022/versions/1
# Out:
# NYC_Weather_2016_2022.csv

# %%
# !mv /root/.cache/kagglehub/datasets/aadimator/nyc-weather-2016-to-2022/versions/1/NYC_Weather_2016_2022.csv /content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/

# %%
nyc_weather_2016_2022_data_path = "/content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/NYC_Weather_2016_2022.csv"

# %%
nyc_weather_2016_2022_data_df = pd.read_csv(nyc_weather_2016_2022_data_path)

# %%
nyc_weather_2016_2022_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59760 entries, 0 to 59759
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   time                   59760 non-null  object
#  1   temperature_2m (°C)    59592 non-null  float64
#  2   precipitation (mm)     59592 non-null  float64
#  3   rain (mm)              59592 non-null  float64
#  4   cloudcover (%)         59592 non-null  float64
#  5   cloudcover_low (%)     59592 non-null  float64
#  6   cloudcover_mid (%)     59592 non-null  float64
#  7   cloudcover_high (%)    59592 non-null  float64
#  8   windspeed_10m (km/h)   59592 non-null  float64
#  9   winddirection_10m (°)  59587 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 4.6+ MB

# %%
nyc_weather_2016_2022_data_df[nyc_weather_2016_2022_data_df['time']>='2022-01-01'].shape
# Out:
# (7152, 10)

# %%
nyc_weather_2016_2022_data_df['time'].describe()
# Out:
# count                59760
# unique               59760
# top       2022-10-25T07:00
# freq                     1
# Name: time, dtype: object

# %%
nyc_weather_2016_2022_data_df['time'].plot

# %%
nyc_weather_2016_2022_data_df['time'] = pd.to_datetime(nyc_weather_2016_2022_data_df['time'])

# %%
plt.figure(figsize=(12, 6))
plt.plot(nyc_weather_2016_2022_data_df['time'], nyc_weather_2016_2022_data_df['temperature_2m (°C)'])
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(nyc_weather_2016_2022_data_df['time'], nyc_weather_2016_2022_data_df['windspeed_10m (km/h)'])
plt.xlabel('Time')
plt.ylabel('Windspeed (km/h)')
plt.title('Windspeed over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(nyc_weather_2016_2022_data_df['time'], nyc_weather_2016_2022_data_df['precipitation (mm)'])
plt.xlabel('Time')
plt.ylabel('Precipitation (mm)')
plt.title('Precipitation over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(nyc_weather_2016_2022_data_df['time'], nyc_weather_2016_2022_data_df['rain (mm)'])
plt.xlabel('Time')
plt.ylabel('Rain (mm)')
plt.title('Rain over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(nyc_weather_2016_2022_data_df['time'], nyc_weather_2016_2022_data_df['cloudcover (%)'])
plt.xlabel('Time')
plt.ylabel('Cloudcover (%)')
plt.title('Cloudcover over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(nyc_weather_2016_2022_data_df['time'], nyc_weather_2016_2022_data_df['winddirection_10m (°)'])
plt.xlabel('Time')
plt.ylabel('Wind Direction (°)')
plt.title('Wind Direction over Time')
plt.grid(True)
plt.show()

# %%
correlation_matrix = nyc_weather_2016_2022_data_df.corr(numeric_only=True)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Weather Variables')
plt.show()

# %%
nyc_weather_2016_2022_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59760 entries, 0 to 59759
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   time                   59760 non-null  object
#  1   temperature_2m (°C)    59592 non-null  float64
#  2   precipitation (mm)     59592 non-null  float64
#  3   rain (mm)              59592 non-null  float64
#  4   cloudcover (%)         59592 non-null  float64
#  5   cloudcover_low (%)     59592 non-null  float64
#  6   cloudcover_mid (%)     59592 non-null  float64
#  7   cloudcover_high (%)    59592 non-null  float64
#  8   windspeed_10m (km/h)   59592 non-null  float64
#  9   winddirection_10m (°)  59587 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 4.6+ MB

# %% [markdown]
# ## New York Weather Data 2023 (heqiang01/hourly-weather-data-in-2023-in-usa)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("heqiang01/hourly-weather-data-in-2023-in-usa")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 5.01M/5.01M [00:00<00:00, 73.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/heqiang01/hourly-weather-data-in-2023-in-usa/versions/1

# %%
# !ls /root/.cache/kagglehub/datasets/heqiang01/hourly-weather-data-in-2023-in-usa/versions/1
# Out:
# 'Boston Weather Data.xlsx'    'San Francisco Weather Data.xlsx'
# 'Chicago Weather Data.xlsx'   'Washington Weather Data.xlsx'
# 'New York Weather Data.xlsx'

# %%
# !mv /root/.cache/kagglehub/datasets/heqiang01/hourly-weather-data-in-2023-in-usa/versions/1/* /content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/

# %%
# !ls /content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/
# Out:
# 'Boston Weather Data.xlsx'     NYC_Weather_2016_2022.csv
# 'Chicago Weather Data.xlsx'   'San Francisco Weather Data.xlsx'
# 'New York Weather Data.xlsx'  'Washington Weather Data.xlsx'

# %%
nyc_weather_2023_xlsx_data_path = "/content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/New York Weather Data.xlsx"

# %%
nyc_weather_2023_xlsx_data_df = pd.read_excel(nyc_weather_2023_xlsx_data_path)

# %%
nyc_weather_2023_xlsx_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9280 entries, 0 to 9279
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dt                   9280 non-null   int64
#  1   dt_iso               9280 non-null   object
#  2   timezone             9280 non-null   int64
#  3   city_name            9280 non-null   object
#  4   lat                  9280 non-null   float64
#  5   lon                  9280 non-null   float64
#  6   temp                 9280 non-null   float64
#  7   visibility           9262 non-null   float64
#  8   dew_point            9280 non-null   float64
#  9   feels_like           9280 non-null   float64
#  10  temp_min             9280 non-null   float64
#  11  temp_max             9280 non-null   float64
#  12  pressure             9280 non-null   int64
#  13  sea_level            0 non-null      float64
#  14  grnd_level           0 non-null      float64
# ...

# %%
nyc_weather_2023_xlsx_data_df.isna().sum()
# Out:
# dt                        0
# dt_iso                    0
# timezone                  0
# city_name                 0
# lat                       0
# lon                       0
# temp                      0
# visibility               18
# dew_point                 0
# feels_like                0
# temp_min                  0
# temp_max                  0
# pressure                  0
# sea_level              9280
# grnd_level             9280
# humidity                  0
# wind_speed                0
# wind_deg                  0
# wind_gust              4649
# rain_1h                7275
# rain_3h                9092
# snow_1h                9268
# snow_3h                9280
# clouds_all                0
# weather_id                0
# weather_main              0
# weather_description       0
# weather_icon              0
# dtype: int64

# %%
nyc_weather_2023_xlsx_data_df.shape
# Out:
# (9280, 28)

# %%
nyc_weather_2023_xlsx_data_df['city_name'].value_counts()
# Out:
# city_name
# New York    9280
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.scatter(nyc_weather_2023_xlsx_data_df['dt'], nyc_weather_2023_xlsx_data_df['humidity'], label='Humidity')
plt.scatter(nyc_weather_2023_xlsx_data_df['dt'], nyc_weather_2023_xlsx_data_df['temp'], label='Temperature')
plt.scatter(nyc_weather_2023_xlsx_data_df['dt'], nyc_weather_2023_xlsx_data_df['wind_speed'], label='Wind Speed')
plt.xlabel('Date and Time')
plt.ylabel('Value')
plt.title('Humidity and Temperature over Time in New York City (2023)')
plt.legend()
plt.grid(True)
plt.show()

# %%
nyc_weather_2023_xlsx_data_df['dt'].head()
# Out:
# 0    1672531200
# 1    1672531200
# 2    1672534800
# 3    1672534800
# 4    1672538400
# Name: dt, dtype: int64

# %%
nyc_weather_2023_xlsx_data_df.describe()
# Out:
#                  dt      timezone           lat           lon         temp  \
# count  9.280000e+03   9280.000000  9.280000e+03  9.280000e+03  9280.000000
# mean   1.688312e+09 -15653.793103  4.071278e+01 -7.400597e+01    14.236820
# std    9.136156e+06   1715.218659  5.393310e-12  1.605913e-12     8.270332
# min    1.672531e+09 -18000.000000  4.071278e+01 -7.400597e+01   -14.870000
# 25%    1.680368e+09 -18000.000000  4.071278e+01 -7.400597e+01     7.417500
# 50%    1.688337e+09 -14400.000000  4.071278e+01 -7.400597e+01    13.770000
# 75%    1.696162e+09 -14400.000000  4.071278e+01 -7.400597e+01    21.400000
# max    1.704064e+09 -14400.000000  4.071278e+01 -7.400597e+01    34.370000
#
#          visibility    dew_point   feels_like     temp_min     temp_max  ...  \
# count   9262.000000  9280.000000  9280.000000  9280.000000  9280.000000  ...
# mean    9575.560894     7.722663    12.852043    13.198805    15.265103  ...
# ...

# %% [markdown]
# ## Import Weather Data for 2024 (sheemazain/weather-data-2024)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sheemazain/weather-data-2024")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 42.6M/42.6M [00:00<00:00, 107MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/sheemazain/weather-data-2024/versions/1

# %%
# !ls /root/.cache/kagglehub/datasets/sheemazain/weather-data-2024/versions/1
# Out:
# weather_data.csv

# %%
# !mv /root/.cache/kagglehub/datasets/sheemazain/weather-data-2024/versions/1/weather_data.csv /content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2024.csv

# %%
# !ls /content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2024.csv
# Out:
# /content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2024.csv

# %%
weather_2024_xlsx_data_path = "/content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2024.csv"

# %%
weather_2024_xlsx_data_df = pd.read_csv(weather_2024_xlsx_data_path)

# %%
weather_2024_xlsx_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Location          1000000 non-null  object
#  1   Date_Time         1000000 non-null  object
#  2   Temperature_C     1000000 non-null  float64
#  3   Humidity_pct      1000000 non-null  float64
#  4   Precipitation_mm  1000000 non-null  float64
#  5   Wind_Speed_kmh    1000000 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 45.8+ MB

# %% [markdown]
# ## New York Weather Data 2023 (haverstein/new-york-weather-data)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("haverstein/new-york-weather-data")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'new-york-weather-data' dataset.
# Path to dataset files: /kaggle/input/new-york-weather-data

# %%
# !ls /kaggle/input/new-york-weather-data/
# Out:
# weather.csv

# %%
# !cp /kaggle/input/new-york-weather-data/weather.csv /content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2023.csv

# %%
# !ls /content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2023.csv
# Out:
# /content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2023.csv

# %%
weather_2023_csv_data_path = "/content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2023.csv"

# %%
weather_2023_csv_data_df = pd.read_csv(weather_2023_csv_data_path)

# %%
weather_2023_csv_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1637 entries, 0 to 1636
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        1637 non-null   object
#  1   Time         1637 non-null   object
#  2   Temperature  1637 non-null   object
#  3   Weather      1637 non-null   object
#  4   Wind         1597 non-null   object
#  5   Humidity     1637 non-null   object
#  6   Visibility   1637 non-null   object
# dtypes: object(7)
# memory usage: 89.7+ KB

# %%
weather_2023_csv_data_df.describe()
# Out:
#                     Month   Time Temperature Weather     Wind Humidity  \
# count                1637   1637        1637    1637     1597     1637
# unique                 61    370          28      30       13       63
# top     18 September 2023  20:51       17 °C  Clear.  No wind      93%
# freq                   49     61         177     377      424      206
#
#        Visibility
# count        1637
# unique         13
# top         16 km
# freq         1079

# %%
weather_2023_csv_data_df.head()
# Out:
#               Month             Time Temperature Weather     Wind Humidity  \
# 0  1 September 2023  00:51Fri, 1 Sep       19 °C  Clear.   7 km/h      47%
# 1  1 September 2023            01:51       19 °C  Clear.  11 km/h      47%
# 2  1 September 2023            02:51       18 °C  Clear.   9 km/h      50%
# 3  1 September 2023            03:51       17 °C  Clear.   7 km/h      50%
# 4  1 September 2023            04:51       17 °C  Clear.  11 km/h      52%
#
#   Visibility
# 0      16 km
# 1      16 km
# 2      16 km
# 3      16 km
# 4      16 km

# %% [markdown]
# ##Start From Here

# %% [markdown]
# ## Load Raw Data

# %%
# Path for Weather Data CSV and Excel
nyc_weather_2016_2022_data_path = "/content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/NYC_Weather_2016_2022.csv"
nyc_weather_2023_xlsx_data_path = "/content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/New York Weather Data.xlsx"
weather_2024_xlsx_data_path = "/content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2024.csv"
weather_2023_csv_data_path = "/content/drive/MyDrive/DataSets/MSResearch/nyc-weather-2016-to-2022/weather_data_2023.csv"

# %%
#Load Weather Data to DataFrames
nyc_weather_2016_2022_data_df = pd.read_csv(nyc_weather_2016_2022_data_path)

# %%
nyc_weather_2023_xlsx_data_df = pd.read_excel(nyc_weather_2023_xlsx_data_path)

# %%
weather_2024_xlsx_data_df = pd.read_csv(weather_2024_xlsx_data_path)

# %%
weather_2023_csv_data_df = pd.read_csv(weather_2023_csv_data_path)

# %%
print(weather_2023_csv_data_df.shape)
print(weather_2024_xlsx_data_df.shape)
print(nyc_weather_2016_2022_data_df.shape)
print(nyc_weather_2023_xlsx_data_df.shape)
# Out:
# (1637, 7)
# (1000000, 6)
# (59760, 10)
# (9280, 28)

# %%
print("nyc_weather_2016_2022_data_df",nyc_weather_2016_2022_data_df.columns)
print("nyc_weather_2023_xlsx_data_df",nyc_weather_2023_xlsx_data_df.columns)
print("weather_2024_xlsx_data_df",weather_2024_xlsx_data_df.columns)
print("weather_2023_csv_data_df",weather_2023_csv_data_df.columns)
# Out:
# nyc_weather_2016_2022_data_df Index(['time', 'temperature_2m (°C)', 'precipitation (mm)', 'rain (mm)',
#        'cloudcover (%)', 'cloudcover_low (%)', 'cloudcover_mid (%)',
#        'cloudcover_high (%)', 'windspeed_10m (km/h)', 'winddirection_10m (°)'],
#       dtype='object')
# nyc_weather_2023_xlsx_data_df Index(['dt', 'dt_iso', 'timezone', 'city_name', 'lat', 'lon', 'temp',
#        'visibility', 'dew_point', 'feels_like', 'temp_min', 'temp_max',
#        'pressure', 'sea_level', 'grnd_level', 'humidity', 'wind_speed',
#        'wind_deg', 'wind_gust', 'rain_1h', 'rain_3h', 'snow_1h', 'snow_3h',
#        'clouds_all', 'weather_id', 'weather_main', 'weather_description',
#        'weather_icon'],
#       dtype='object')
# weather_2024_xlsx_data_df Index(['Location', 'Date_Time', 'Temperature_C', 'Humidity_pct',
#        'Precipitation_mm', 'Wind_Speed_kmh'],
#       dtype='object')
# weather_2023_csv_data_df Index(['Month', 'Time', 'Temperature', 'Weather', 'Wind', 'Humidity',
# ...

# %%
weather_df_dic = {"weather_2016_2022_10cols":nyc_weather_2016_2022_data_df,
                  "weather_2023_28cols": nyc_weather_2023_xlsx_data_df,
                  "weather_2023_7cols": weather_2023_csv_data_df,
                  "weather_2024_6cols": weather_2024_xlsx_data_df}

# %% [markdown]
# ### Process columns for consistency

# %%
weather_2023_csv_data_df.head()
# Out:
#               Month             Time Temperature Weather     Wind Humidity  \
# 0  1 September 2023  00:51Fri, 1 Sep       19 °C  Clear.   7 km/h      47%
# 1  1 September 2023            01:51       19 °C  Clear.  11 km/h      47%
# 2  1 September 2023            02:51       18 °C  Clear.   9 km/h      50%
# 3  1 September 2023            03:51       17 °C  Clear.   7 km/h      50%
# 4  1 September 2023            04:51       17 °C  Clear.  11 km/h      52%
#
#   Visibility
# 0      16 km
# 1      16 km
# 2      16 km
# 3      16 km
# 4      16 km

# %%
weather_2023_csv_data_df[['Month','Time']].head()
# Out:
#               Month             Time
# 0  1 September 2023  00:51Fri, 1 Sep
# 1  1 September 2023            01:51
# 2  1 September 2023            02:51
# 3  1 September 2023            03:51
# 4  1 September 2023            04:51

# %%
df = weather_2023_csv_data_df.copy()

# %%
print(df['Month'].value_counts())
print(df['Time'].value_counts())
# Out:
# Month
# 18 September 2023    49
# 21 October 2023      41
# 25 September 2023    40
# 11 September 2023    40
# 20 October 2023      39
#                      ..
# 25 October 2023      23
# 1 October 2023       22
# 7 September 2023     22
# 22 October 2023      22
# 6 September 2023     21
# Name: count, Length: 61, dtype: int64
# Time
# 20:51               61
# 06:51               59
# 18:51               58
# 23:51               58
# 12:51               58
#                     ..
# 05:23                1
# 05:07                1
# 01:35                1
# 01:02Mon, 30 Oct     1
# 23:04                1
# Name: count, Length: 370, dtype: int64

# %%
weather_2023_csv_data_df[~weather_2023_csv_data_df['Time'].str.fullmatch(r'\d{2}:\d{2}', na=False)]['Time']
# Out:
# 0        00:51Fri, 1 Sep
# 23       00:51Sat, 2 Sep
# 46       00:51Sun, 3 Sep
# 69       00:51Mon, 4 Sep
# 92       00:51Tue, 5 Sep
#               ...
# 1506    00:51Fri, 27 Oct
# 1529    00:51Sat, 28 Oct
# 1552    00:51Sun, 29 Oct
# 1585    01:02Mon, 30 Oct
# 1614    00:51Tue, 31 Oct
# Name: Time, Length: 61, dtype: object

# %%
weather_2023_csv_data_df['Time'] = weather_2023_csv_data_df['Time'].str[:5]

# %%
weather_2023_csv_data_df['Time'].str.fullmatch(r'\d{2}:\d{2}', na=False).value_counts()
# Out:
# Time
# True    1637
# Name: count, dtype: int64

# %%
weather_2023_csv_data_df.head()
# Out:
#               Month   Time Temperature Weather     Wind Humidity Visibility
# 0  1 September 2023  00:51       19 °C  Clear.   7 km/h      47%      16 km
# 1  1 September 2023  01:51       19 °C  Clear.  11 km/h      47%      16 km
# 2  1 September 2023  02:51       18 °C  Clear.   9 km/h      50%      16 km
# 3  1 September 2023  03:51       17 °C  Clear.   7 km/h      50%      16 km
# 4  1 September 2023  04:51       17 °C  Clear.  11 km/h      52%      16 km

# %%
weather_2023_csv_data_df['Date_Time'] = weather_2023_csv_data_df['Month'] + ' ' + weather_2023_csv_data_df['Time']

# %%
weather_2023_csv_data_df.head()
# Out:
#               Month   Time Temperature Weather     Wind Humidity Visibility  \
# 0  1 September 2023  00:51       19 °C  Clear.   7 km/h      47%      16 km
# 1  1 September 2023  01:51       19 °C  Clear.  11 km/h      47%      16 km
# 2  1 September 2023  02:51       18 °C  Clear.   9 km/h      50%      16 km
# 3  1 September 2023  03:51       17 °C  Clear.   7 km/h      50%      16 km
# 4  1 September 2023  04:51       17 °C  Clear.  11 km/h      52%      16 km
#
#                 Date_Time
# 0  1 September 2023 00:51
# 1  1 September 2023 01:51
# 2  1 September 2023 02:51
# 3  1 September 2023 03:51
# 4  1 September 2023 04:51

# %%
weather_2023_csv_data_df['Date_Time'] = pd.to_datetime(weather_2023_csv_data_df['Date_Time'], errors='coerce')

# %%
weather_2023_csv_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1637 entries, 0 to 1636
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        1637 non-null   object
#  1   Time         1637 non-null   object
#  2   Temperature  1637 non-null   object
#  3   Weather      1637 non-null   object
#  4   Wind         1597 non-null   object
#  5   Humidity     1637 non-null   object
#  6   Visibility   1637 non-null   object
#  7   Date_Time    1637 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(7)
# memory usage: 102.4+ KB

# %%
weather_2023_csv_data_df.head()
# Out:
#               Month   Time Temperature Weather     Wind Humidity Visibility  \
# 0  1 September 2023  00:51       19 °C  Clear.   7 km/h      47%      16 km
# 1  1 September 2023  01:51       19 °C  Clear.  11 km/h      47%      16 km
# 2  1 September 2023  02:51       18 °C  Clear.   9 km/h      50%      16 km
# 3  1 September 2023  03:51       17 °C  Clear.   7 km/h      50%      16 km
# 4  1 September 2023  04:51       17 °C  Clear.  11 km/h      52%      16 km
#
#             Date_Time
# 0 2023-09-01 00:51:00
# 1 2023-09-01 01:51:00
# 2 2023-09-01 02:51:00
# 3 2023-09-01 03:51:00
# 4 2023-09-01 04:51:00

# %% [markdown]
# ## Weather Data 2024

# %%
weather_2024_xlsx_data_df.head()
# Out:
#        Location            Date_Time  Temperature_C  Humidity_pct  \
# 0     San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1     San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2     San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3  Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4   San Antonio  2024-04-29 13:23:51      39.808213     72.899908
#
#    Precipitation_mm  Wind_Speed_kmh
# 0          4.020119        8.233540
# 1          9.111623       27.715161
# 2          4.607511       28.732951
# 3          3.183720       26.367303
# 4          9.598282       29.898622

# %%
weather_2024_xlsx_data_df['Date_Time'].describe()
# Out:
# count                 1000000
# unique                 959526
# top       2024-05-11 23:55:43
# freq                        4
# Name: Date_Time, dtype: object

# %%
weather_2024_xlsx_data_df['Date_Time'] = pd.to_datetime(weather_2024_xlsx_data_df['Date_Time'], errors='coerce')

# %%
weather_2024_xlsx_data_df['Location'].value_counts()
# Out:
# Location
# Phoenix         100209
# Chicago         100164
# Philadelphia    100122
# Houston         100076
# New York         99972
# San Antonio      99962
# Dallas           99936
# Los Angeles      99922
# San Jose         99863
# San Diego        99774
# Name: count, dtype: int64

# %%
weather_2024_xlsx_data_df = weather_2024_xlsx_data_df[weather_2024_xlsx_data_df['Location'] == 'New York']

# %%
weather_2024_xlsx_data_df.shape
# Out:
# (99972, 6)

# %%
weather_2024_xlsx_data_df.head()
# Out:
#     Location            Date_Time  Temperature_C  Humidity_pct  \
# 7   New York  2024-01-25 19:04:34      -6.894766     30.804894
# 8   New York  2024-03-29 05:20:30       0.963545     38.819158
# 10  New York  2024-03-04 13:47:15      35.145559     54.752866
# 21  New York  2024-02-19 12:26:07      -7.383811     54.089973
# 28  New York  2024-01-04 21:41:10      14.568328     41.350180
#
#     Precipitation_mm  Wind_Speed_kmh
# 7           8.027624       16.848337
# 8           3.640129        7.989024
# 10          8.349195       25.430310
# 21          1.905731        6.637064
# 28          3.342765        4.781286

# %%
weather_2024_xlsx_data_df.sort_values(by='Date_Time', inplace=True)

# %%
weather_2024_xlsx_data_df['Date_Time'].isna().sum()
# Out:
# np.int64(0)

# %%
weather_2024_xlsx_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99972 entries, 756040 to 324735
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          99972 non-null  object
#  1   Date_Time         99972 non-null  object
#  2   Temperature_C     99972 non-null  float64
#  3   Humidity_pct      99972 non-null  float64
#  4   Precipitation_mm  99972 non-null  float64
#  5   Wind_Speed_kmh    99972 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 5.3+ MB

# %%
# Extract year and month from 'Datetime' and count occurrences
weather_2024_xlsx_data_df['year_month'] = weather_2024_xlsx_data_df['Date_Time'].dt.to_period('M')
year_month_counts = weather_2024_xlsx_data_df['year_month'].value_counts().sort_index()

# Display the counts
display(year_month_counts)
# Out:
# year_month
# 2024-01    22156
# 2024-02    20927
# 2024-03    22404
# 2024-04    21636
# 2024-05    12849
# Freq: M, Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
year_month_counts.plot(kind='bar')
plt.title('Number of Entries per Year-Month')
plt.xlabel('Year-Month')
plt.ylabel('Number of Entries')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter for sublink_id = 1
date_time_df = weather_2024_xlsx_data_df['Date_Time'].copy()
date_time_df = pd.to_datetime(date_time_df)

# Plot the Datetime column
plt.figure(figsize=(12, 6))
plt.plot(date_time_df)
plt.title('Datetime for date-time-df')
plt.xlabel('Index')
plt.ylabel('Date_Time')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=weather_2024_xlsx_data_df, x=weather_2024_xlsx_data_df['Date_Time'], y='Wind_Speed_kmh')
plt.title('Wind Speed (km/h) over Time')
plt.xlabel('Year-Month')
plt.ylabel('Wind Speed (km/h)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=weather_2024_xlsx_data_df, x=weather_2024_xlsx_data_df['Date_Time'], y='Temperature_C')
plt.title('Temperature_C over Time')
plt.xlabel('Date-Time')
plt.ylabel('Temperature_C')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
weather_2024_xlsx_data_df[weather_2024_xlsx_data_df['year_month']=='2024-01'].head(100)
# Out:
#         Location           Date_Time  Temperature_C  Humidity_pct  \
# 756040  New York 2024-01-01 00:04:45      37.991348     64.202440
# 376731  New York 2024-01-01 00:04:52       8.191753     62.335497
# 178214  New York 2024-01-01 00:04:55      26.772471     87.385380
# 769287  New York 2024-01-01 00:08:07       9.503127     76.844316
# 109092  New York 2024-01-01 00:09:15      37.375306     44.161119
# ...          ...                 ...            ...           ...
# 500036  New York 2024-01-01 03:12:44      34.142931     38.173609
# 812811  New York 2024-01-01 03:12:51       1.343577     32.755022
# 352900  New York 2024-01-01 03:13:59       5.311120     44.696245
# 199286  New York 2024-01-01 03:14:36      25.712028     54.443369
# 864924  New York 2024-01-01 03:14:38      36.000621     71.593924
#
#         Precipitation_mm  Wind_Speed_kmh year_month
# 756040          0.050219       24.157506    2024-01
# 376731          8.601657        0.612134    2024-01
# ...

# %%
# Filter for January 2024
january_2024_data = weather_2024_xlsx_data_df[weather_2024_xlsx_data_df['Date_Time'].dt.to_period('M') == '2024-01']

plt.figure(figsize=(8, 6))
sns.boxplot(data=january_2024_data, y='Temperature_C')
plt.title('Temperature Distribution in January 2024')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.show()

# %%
# Filter for January 2024 (assuming january_2024_data is already defined from the previous step)
# If not, you might need to redefine it:
january_2024_data = weather_2024_xlsx_data_df[weather_2024_xlsx_data_df['Date_Time'].dt.to_period('M') == '2024-01'].copy()


# Bucketize Temperature_C into 10 bins
january_2024_data['Temperature_C_bins'] = pd.cut(january_2024_data['Temperature_C'], bins=10)

# Count the occurrences in each bin
temperature_bin_counts = january_2024_data['Temperature_C_bins'].value_counts().sort_index()

# Plot a bar chart of the counts
plt.figure(figsize=(10, 6))
temperature_bin_counts.plot(kind='bar')
plt.title('Distribution of Temperature Bins in January 2024')
plt.xlabel('Temperature Bins (°C)')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-354405206.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   january_2024_data['Temperature_C_bins'] = pd.cut(january_2024_data['Temperature_C'], bins=10)

# %% [markdown]
# ## New York Weather data 2016-2022

# %%
nyc_weather_2016_2022_data_df.head()
# Out:
#                time  temperature_2m (°C)  precipitation (mm)  rain (mm)  \
# 0  2016-01-01T00:00                  7.6                 0.0        0.0
# 1  2016-01-01T01:00                  7.5                 0.0        0.0
# 2  2016-01-01T02:00                  7.1                 0.0        0.0
# 3  2016-01-01T03:00                  6.6                 0.0        0.0
# 4  2016-01-01T04:00                  6.3                 0.0        0.0
#
#    cloudcover (%)  cloudcover_low (%)  cloudcover_mid (%)  \
# 0            69.0                53.0                 0.0
# 1            20.0                 4.0                 0.0
# 2            32.0                 3.0                 0.0
# 3            35.0                 5.0                 0.0
# 4            34.0                 4.0                 0.0
#
#    cloudcover_high (%)  windspeed_10m (km/h)  winddirection_10m (°)
# 0                 72.0                  10.0                  296.0
# ...

# %%
nyc_weather_2016_2022_data_df['time'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 59760 entries, 0 to 59759
# Series name: time
# Non-Null Count  Dtype
# --------------  -----
# 59760 non-null  object
# dtypes: object(1)
# memory usage: 467.0+ KB

# %%
nyc_weather_2016_2022_data_df['time'] = pd.to_datetime(nyc_weather_2016_2022_data_df['time'], errors='coerce')

# %%
nyc_weather_2023_xlsx_data_df.head()
# Out:
#            dt                         dt_iso  timezone city_name        lat  \
# 0  1672531200  2023-01-01 00:00:00 +0000 UTC    -18000  New York  40.712775
# 1  1672531200  2023-01-01 00:00:00 +0000 UTC    -18000  New York  40.712775
# 2  1672534800  2023-01-01 01:00:00 +0000 UTC    -18000  New York  40.712775
# 3  1672534800  2023-01-01 01:00:00 +0000 UTC    -18000  New York  40.712775
# 4  1672538400  2023-01-01 02:00:00 +0000 UTC    -18000  New York  40.712775
#
#          lon   temp  visibility  dew_point  feels_like  ...  wind_gust  \
# 0 -74.005973   9.33      2414.0       8.57        7.65  ...        0.0
# 1 -74.005973   9.33      2414.0       8.57        7.65  ...        0.0
# 2 -74.005973   9.17      2816.0       8.41        7.77  ...        0.0
# 3 -74.005973   9.17      2816.0       8.41        7.77  ...        0.0
# 4 -74.005973  10.05         NaN       9.44        9.62  ...        0.0
#
#    rain_1h  rain_3h  snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# ...

# %%
# Convert 'dt' (Unix timestamp) to datetime
nyc_weather_2023_xlsx_data_df['dt'] = pd.to_datetime(nyc_weather_2023_xlsx_data_df['dt'], unit='s', errors='coerce')

# %%
# Convert 'dt_iso' to datetime, assuming it is already in UTC
nyc_weather_2023_xlsx_data_df['dt_iso'] = pd.to_datetime(nyc_weather_2023_xlsx_data_df['dt_iso'], utc=True, errors='coerce')
# Out:
# /tmp/ipython-input-3916456547.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   nyc_weather_2023_xlsx_data_df['dt_iso'] = pd.to_datetime(nyc_weather_2023_xlsx_data_df['dt_iso'], utc=True, errors='coerce')

# %%
# Convert timezone offset (in seconds) to timedelta and add to 'dt' for localized time
nyc_weather_2023_xlsx_data_df['dt_localized'] = nyc_weather_2023_xlsx_data_df['dt'] + pd.to_timedelta(nyc_weather_2023_xlsx_data_df['timezone'], unit='s')

# %%
# Display info to check the updated dtypes and new column
nyc_weather_2023_xlsx_data_df[['dt', 'dt_iso', 'dt_localized', 'timezone']].head()
# Out:
#                    dt dt_iso        dt_localized  timezone
# 0 2023-01-01 00:00:00    NaT 2022-12-31 19:00:00    -18000
# 1 2023-01-01 00:00:00    NaT 2022-12-31 19:00:00    -18000
# 2 2023-01-01 01:00:00    NaT 2022-12-31 20:00:00    -18000
# 3 2023-01-01 01:00:00    NaT 2022-12-31 20:00:00    -18000
# 4 2023-01-01 02:00:00    NaT 2022-12-31 21:00:00    -18000

# %%
nyc_weather_2023_xlsx_data_df.drop(columns=['dt_localized'], inplace=True)

# %% [markdown]
# ## Checkpoint: 1: Load Preprocessed Date and Time aligned data

# %%
temp_directory_path = '/content/drive/MyDrive/DataSets/MSResearch/30Sep/'

# %%
import os

# Create the directory if it doesn't exist
if not os.path.exists(temp_directory_path):
    os.makedirs(temp_directory_path)
    print(f"Directory '{temp_directory_path}' created.")
else:
    print(f"Directory '{temp_directory_path}' already exists.")
# Out:
# Directory '/content/drive/MyDrive/DataSets/MSResearch/30Sep/' already exists.

# %% [markdown]
# ### Save Preprocessed Data with Date and Time Aligned

# %%
### Write Preprocessed Stats with time aligned
nyc_weather_2016_2022_data_df.to_csv(temp_directory_path+"nyc_weather_2016_2022_data_df_preprocessed.csv", index=False)

# %%
nyc_weather_2023_xlsx_data_df.to_csv(temp_directory_path+"nyc_weather_2023_xlsx_data_df_preprocessed.csv", index=False)

# %%
weather_2023_csv_data_df.to_csv(temp_directory_path+"weather_2023_csv_data_df_preprocessed.csv", index=False)

# %%
weather_2024_xlsx_data_df.to_csv(temp_directory_path+"weather_2024_xlsx_data_df.csv", index=False)

# %% [markdown]
# ### API to Load Checkpoint files

# %%
def load_preprocessed_data(file_path):
  global nyc_weather_2016_2022_data_df, nyc_weather_2023_xlsx_data_df, weather_2023_csv_data_df, weather_2024_xlsx_data_df
  nyc_weather_2016_2022_data_df = pd.read_csv(file_path+"nyc_weather_2016_2022_data_df_preprocessed.csv")
  nyc_weather_2023_xlsx_data_df = pd.read_csv(file_path+"nyc_weather_2023_xlsx_data_df_preprocessed.csv")
  weather_2023_csv_data_df = pd.read_csv(file_path+"weather_2023_csv_data_df_preprocessed.csv")
  weather_2024_xlsx_data_df = pd.read_csv(file_path+"weather_2024_xlsx_data_df.csv")

# %%
load_preprocessed_data(temp_directory_path)

# %%
weather_2024_xlsx_data_df.head()
# Out:
#        Location            Date_Time  Temperature_C  Humidity_pct  \
# 0     San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1     San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2     San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3  Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4   San Antonio  2024-04-29 13:23:51      39.808213     72.899908
#
#    Precipitation_mm  Wind_Speed_kmh
# 0          4.020119        8.233540
# 1          9.111623       27.715161
# 2          4.607511       28.732951
# 3          3.183720       26.367303
# 4          9.598282       29.898622

# %%
weather_2024_xlsx_data_df['Location'].value_counts()
# Out:
# Location
# Phoenix         100209
# Chicago         100164
# Philadelphia    100122
# Houston         100076
# New York         99972
# San Antonio      99962
# Dallas           99936
# Los Angeles      99922
# San Jose         99863
# San Diego        99774
# Name: count, dtype: int64

# %%
weather_2024_xlsx_data_df = weather_2024_xlsx_data_df[weather_2024_xlsx_data_df['Location'] == 'New York']

# %%
weather_2024_xlsx_data_df.shape
# Out:
# (99972, 6)

# %%
weather_2024_xlsx_data_df.drop(columns=['Location', 'Precipitation_mm'], inplace=True)

# %%
weather_2024_xlsx_data_df.head()
# Out:
#               Date_Time  Temperature_C  Humidity_pct  Wind_Speed_kmh
# 7   2024-01-25 19:04:34      -6.894766     30.804894       16.848337
# 8   2024-03-29 05:20:30       0.963545     38.819158        7.989024
# 10  2024-03-04 13:47:15      35.145559     54.752866       25.430310
# 21  2024-02-19 12:26:07      -7.383811     54.089973        6.637064
# 28  2024-01-04 21:41:10      14.568328     41.350180        4.781286

# %%
weather_2023_csv_data_df.head()
# Out:
#               Month   Time Temperature Weather     Wind Humidity Visibility  \
# 0  1 September 2023  00:51       19 °C  Clear.   7 km/h      47%      16 km
# 1  1 September 2023  01:51       19 °C  Clear.  11 km/h      47%      16 km
# 2  1 September 2023  02:51       18 °C  Clear.   9 km/h      50%      16 km
# 3  1 September 2023  03:51       17 °C  Clear.   7 km/h      50%      16 km
# 4  1 September 2023  04:51       17 °C  Clear.  11 km/h      52%      16 km
#
#              Date_Time
# 0  2023-09-01 00:51:00
# 1  2023-09-01 01:51:00
# 2  2023-09-01 02:51:00
# 3  2023-09-01 03:51:00
# 4  2023-09-01 04:51:00

# %%
weather_2023_csv_data_df.drop(columns=['Month', 'Time', 'Weather', 'Visibility'], inplace=True)

# %%
weather_2023_csv_data_df.head()
# Out:
#   Temperature     Wind Humidity            Date_Time
# 0       19 °C   7 km/h      47%  2023-09-01 00:51:00
# 1       19 °C  11 km/h      47%  2023-09-01 01:51:00
# 2       18 °C   9 km/h      50%  2023-09-01 02:51:00
# 3       17 °C   7 km/h      50%  2023-09-01 03:51:00
# 4       17 °C  11 km/h      52%  2023-09-01 04:51:00

# %%
weather_2023_csv_data_df.rename(columns={'Temperature':'Temperature_C',	'Humidity':'Humidity_pct', 'Wind':'Wind_Speed_kmh'}, inplace=True)

# %%
weather_2023_csv_data_df['Temperature_C'] = weather_2023_csv_data_df['Temperature_C'].str.replace('°C', '')

# %%
weather_2023_csv_data_df['Wind_Speed_kmh'] = weather_2023_csv_data_df['Wind_Speed_kmh'].str.replace('km/h', '')

# %%
weather_2023_csv_data_df['Humidity_pct'] = weather_2023_csv_data_df['Humidity_pct'].str.replace('%', '')

# %%
weather_2023_csv_data_df.head()
# Out:
#   Temperature_C Wind_Speed_kmh Humidity_pct            Date_Time
# 0           19              7            47  2023-09-01 00:51:00
# 1           19             11            47  2023-09-01 01:51:00
# 2           18              9            50  2023-09-01 02:51:00
# 3           17              7            50  2023-09-01 03:51:00
# 4           17             11            52  2023-09-01 04:51:00

# %%
weather_2023_csv_data_df.shape, weather_2024_xlsx_data_df.shape
# Out:
# ((1637, 4), (99972, 4))

# %%
# Append weather_2023_csv_data_df and weather_2024_xlsx_data_df
weather_2023_2024_df = pd.concat([weather_2023_csv_data_df, weather_2024_xlsx_data_df], ignore_index=True)
print(weather_2023_2024_df.shape)
weather_2023_2024_df.head()
# Out:
# (101609, 4)
#   Temperature_C Wind_Speed_kmh Humidity_pct            Date_Time
# 0           19              7            47  2023-09-01 00:51:00
# 1           19             11            47  2023-09-01 01:51:00
# 2           18              9            50  2023-09-01 02:51:00
# 3           17              7            50  2023-09-01 03:51:00
# 4           17             11            52  2023-09-01 04:51:00

# %%
weather_2023_2024_df.describe()
# Out:
#        Temperature_C Wind_Speed_kmh Humidity_pct            Date_Time
# count         101609         101569       101609               101609
# unique        100000          99985       100035               101213
# top              17         No wind           93  2024-03-23 04:34:38
# freq             177            424          206                    3

# %%
weather_2023_2024_df['Date_Time'].describe()
# Out:
# count                  101609
# unique                 101213
# top       2024-03-23 04:34:38
# freq                        3
# Name: Date_Time, dtype: object

# %%
# Filter for sublink_id = 1
date_time_df = weather_2023_2024_df['Date_Time'].copy()
date_time_df = pd.to_datetime(date_time_df)

# Plot the Datetime column
plt.figure(figsize=(12, 6))
plt.plot(date_time_df)
plt.title('Datetime for date-time-df')
plt.xlabel('Index')
plt.ylabel('Date_Time')
plt.tight_layout()
plt.show()

# %%
weather_2023_2024_df[weather_2023_2024_df['Date_Time'].str.match("02-02-2024")].shape
# Out:
# (0, 4)

# %%
# Specify the date you want to count
date_to_count = '2023-09-01'

# Convert 'Date_Time' to datetime objects if not already done
weather_2023_2024_df['Date_Time'] = pd.to_datetime(weather_2023_2024_df['Date_Time'])

# Filter the DataFrame for rows matching the specified date and count them
count_for_date = weather_2023_2024_df[weather_2023_2024_df['Date_Time'].dt.date == pd.to_datetime(date_to_count).date()].shape[0]

# Print the count
print(f"Number of entries for {date_to_count}: {count_for_date}")
# Out:
# Number of entries for 2023-09-01: 23

# %%
weather_2023_2024_df[weather_2023_2024_df['Date_Time'].dt.date == pd.to_datetime(date_to_count).date()].head()
# Out:
#      Temperature_C Wind_Speed_kmh Humidity_pct           Date_Time
# 1779     30.878836      23.870979    70.853368 2024-01-31 12:11:53
# 1817     -7.456427       3.506344    84.188365 2024-01-31 16:41:45
# 2096     -4.971678      11.735983    88.321429 2024-01-31 06:56:18
# 3305      5.506951      24.939393    60.831544 2024-01-31 11:44:49
# 3359     34.264901      22.515424    42.296213 2024-01-31 22:34:00

# %%
weather_2023_2024_df.to_csv(temp_directory_path+"weather_2023_2024_df.csv", index=False)

# %% [markdown]
# ## Load 2023_2024 New York Data

# %%
weather_2023_2024_df = pd.read_csv(temp_directory_path+"weather_2023_2024_df.csv")

# %%
weather_2023_2024_df.shape
# Out:
# (101609, 4)

# %%
weather_2023_2024_df.head()
# Out:
#    Temperature_C  Wind_Speed_kmh  Humidity_pct            Date_Time
# 0           19.0             7.0          47.0  2023-09-01 00:51:00
# 1           19.0            11.0          47.0  2023-09-01 01:51:00
# 2           18.0             9.0          50.0  2023-09-01 02:51:00
# 3           17.0             7.0          50.0  2023-09-01 03:51:00
# 4           17.0            11.0          52.0  2023-09-01 04:51:00

# %%
weather_2023_2024_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101609 entries, 0 to 101608
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Temperature_C   101609 non-null  float64
#  1   Wind_Speed_kmh  101569 non-null  float64
#  2   Humidity_pct    101609 non-null  float64
#  3   Date_Time       101609 non-null  object
# dtypes: float64(3), object(1)
# memory usage: 3.1+ MB

# %%
weather_2023_2024_df['Temperature_C'] = weather_2023_2024_df['Temperature_C'].astype(float)

# %%
weather_2023_2024_df[weather_2023_2024_df['Wind_Speed_kmh']=='No wind'].shape
# Out:
# (0, 4)

# %%
weather_2023_2024_df['Wind_Speed_kmh'] = weather_2023_2024_df['Wind_Speed_kmh'].replace('No wind', '0')
weather_2023_2024_df['Wind_Speed_kmh'] = weather_2023_2024_df['Wind_Speed_kmh'].astype(float)

# %%
weather_2023_2024_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101609 entries, 0 to 101608
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Temperature_C   101609 non-null  float64
#  1   Wind_Speed_kmh  101569 non-null  float64
#  2   Humidity_pct    101609 non-null  float64
#  3   Date_Time       101609 non-null  object
# dtypes: float64(3), object(1)
# memory usage: 3.1+ MB

# %%
weather_2023_2024_df.describe()
# Out:
#        Temperature_C  Wind_Speed_kmh   Humidity_pct
# count  101609.000000   101569.000000  101609.000000
# mean       15.060866       14.865403      60.251794
# std        14.311260        8.682240      17.390395
# min        -9.999870        0.000000      30.000231
# 25%         2.747437        7.304219      45.187547
# 50%        15.135610       14.798141      60.192282
# 75%        27.343033       22.420906      75.319807
# max        39.999801       29.999681      97.000000

# %%
weather_2023_2024_df['Date_Time'].isna().sum()
# Out:
# np.int64(0)

# %%
weather_2023_2024_df.to_csv(temp_directory_path+"weather_2023_2024_df.csv", index=False)

# %%
weather_2023_2024_df.head()
# Out:
#    Temperature_C  Wind_Speed_kmh  Humidity_pct            Date_Time
# 0           19.0             7.0          47.0  2023-09-01 00:51:00
# 1           19.0            11.0          47.0  2023-09-01 01:51:00
# 2           18.0             9.0          50.0  2023-09-01 02:51:00
# 3           17.0             7.0          50.0  2023-09-01 03:51:00
# 4           17.0            11.0          52.0  2023-09-01 04:51:00

# %%
nyc_weather_2023_xlsx_data_df[['city_name', 'lat', 'lon', 'weather_id', 'weather_main']].head()
# Out:
#   city_name        lat        lon  weather_id weather_main
# 0  New York  40.712775 -74.005973         500         Rain
# 1  New York  40.712775 -74.005973         701         Mist
# 2  New York  40.712775 -74.005973         500         Rain
# 3  New York  40.712775 -74.005973         701         Mist
# 4  New York  40.712775 -74.005973         501         Rain

# %%
nyc_weather_2023_xlsx_data_df.columns
# Out:
# Index(['dt', 'dt_iso', 'timezone', 'city_name', 'lat', 'lon', 'temp',
#        'visibility', 'dew_point', 'feels_like', 'temp_min', 'temp_max',
#        'pressure', 'sea_level', 'grnd_level', 'humidity', 'wind_speed',
#        'wind_deg', 'wind_gust', 'rain_1h', 'rain_3h', 'snow_1h', 'snow_3h',
#        'clouds_all', 'weather_id', 'weather_main', 'weather_description',
#        'weather_icon'],
#       dtype='object')

# %%
cols_of_interest = ['temp', 'visibility', 'pressure', 'humidity', 'wind_speed',
       'wind_deg', 'wind_gust', 'rain_1h', 'rain_3h', 'snow_1h', 'snow_3h',
       'clouds_all', 'weather_id', 'weather_main', 'weather_description',
       'weather_icon']
nyc_weather_2023_xlsx_data_df[cols_of_interest].describe()
# Out:
#               temp    visibility     pressure     humidity   wind_speed  \
# count  9280.000000   9262.000000  9280.000000  9280.000000  9280.000000
# mean     14.236820   9575.560894  1015.436746    66.818858     5.147942
# std       8.270332   1450.849252     8.090626    18.040950     2.404295
# min     -14.870000    402.000000   983.000000    18.000000     0.000000
# 25%       7.417500  10000.000000  1010.000000    53.000000     3.580000
# 50%      13.770000  10000.000000  1015.000000    67.000000     4.630000
# 75%      21.400000  10000.000000  1021.000000    82.250000     6.260000
# max      34.370000  10000.000000  1040.000000    98.000000    20.600000
#
#           wind_deg    wind_gust      rain_1h     rain_3h    snow_1h  snow_3h  \
# count  9280.000000  4631.000000  2005.000000  188.000000  12.000000      0.0
# mean    203.605711     7.031525     1.374120    2.392553   0.231667      NaN
# std     116.778460     4.742980     2.110176    3.451313   0.114561      NaN
# ...

# %%
nyc_weather_2023_xlsx_data_df[cols_of_interest].head()
# Out:
#     temp  visibility  pressure  humidity  wind_speed  wind_deg  wind_gust  \
# 0   9.33      2414.0      1011        95         3.1       190        0.0
# 1   9.33      2414.0      1011        95         3.1       190        0.0
# 2   9.17      2816.0      1010        95         2.6       160        0.0
# 3   9.17      2816.0      1010        95         2.6       160        0.0
# 4  10.05         NaN      1009        96         1.0       180        0.0
#
#    rain_1h  rain_3h  snow_1h  snow_3h  clouds_all  weather_id weather_main  \
# 0     0.25      NaN      NaN      NaN         100         500         Rain
# 1     0.25      NaN      NaN      NaN         100         701         Mist
# 2     0.81      NaN      NaN      NaN         100         500         Rain
# 3     0.81      NaN      NaN      NaN         100         701         Mist
# 4     1.27      NaN      NaN      NaN         100         501         Rain
#
#   weather_description weather_icon
# ...

# %%
nyc_weather_2023_xlsx_data_df['snow_1h'].value_counts()
# Out:
# snow_1h
# 0.13    2
# 0.28    1
# 0.23    1
# 0.25    1
# 0.16    1
# 0.11    1
# 0.46    1
# 0.39    1
# 0.33    1
# 0.19    1
# 0.12    1
# Name: count, dtype: int64

# %%
cols_to_drop=['snow_1h']

# %%
nyc_weather_2023_xlsx_data_df['snow_3h'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9280 entries, 0 to 9279
# Series name: snow_3h
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      float64
# dtypes: float64(1)
# memory usage: 72.6 KB

# %%
cols_to_drop.append('snow_3h')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-958472001.py in <cell line: 0>()
#       1 cols_to_drop.append('snow_3h')
# ----> 2 cols_to_dorp
#
# NameError: name 'cols_to_dorp' is not defined

# %%
cols_to_drop
# Out:
# ['snow_1h']

# %%
nyc_weather_2023_xlsx_data_df.drop(columns=['snow_1h'], inplace=True)

# %%
weather_2024_xlsx_data_df['Location'].value_counts()
# Out:
# Location
# Phoenix         100209
# Chicago         100164
# Philadelphia    100122
# Houston         100076
# New York         99972
# San Antonio      99962
# Dallas           99936
# Los Angeles      99922
# San Jose         99863
# San Diego        99774
# Name: count, dtype: int64

# %%
#nyc_weather_2016_2022_data_df
#nyc_weather_2023_xlsx_data_df

#weather_2023_csv_data_df
#weather_2024_xlsx_data_df

#weather_df_dic

# %%
for key, value in weather_df_dic.items():
  print(key, value.shape)
  print(key, value.columns)
# Out:
# weather_2016_2022_10cols (59760, 10)
# weather_2016_2022_10cols Index(['time', 'temperature_2m (°C)', 'precipitation (mm)', 'rain (mm)',
#        'cloudcover (%)', 'cloudcover_low (%)', 'cloudcover_mid (%)',
#        'cloudcover_high (%)', 'windspeed_10m (km/h)', 'winddirection_10m (°)'],
#       dtype='object')
# weather_2023_28cols (9280, 27)
# weather_2023_28cols Index(['dt', 'dt_iso', 'timezone', 'city_name', 'lat', 'lon', 'temp',
#        'visibility', 'dew_point', 'feels_like', 'temp_min', 'temp_max',
#        'pressure', 'sea_level', 'grnd_level', 'humidity', 'wind_speed',
#        'wind_deg', 'wind_gust', 'rain_1h', 'rain_3h', 'snow_3h', 'clouds_all',
#        'weather_id', 'weather_main', 'weather_description', 'weather_icon'],
#       dtype='object')
# weather_2023_7cols (1637, 8)
# weather_2023_7cols Index(['Month', 'Time', 'Temperature', 'Weather', 'Wind', 'Humidity',
#        'Visibility', 'Date_Time'],
#       dtype='object')
# weather_2024_6cols (1000000, 6)
# ...

# %%
nyc_weather_2023_xlsx_data_df['dt'].describe()
# Out:
# count                             9280
# mean     2023-07-02 15:36:42.672413696
# min                2023-01-01 00:00:00
# 25%                2023-04-01 16:45:00
# 50%                2023-07-02 22:30:00
# 75%                2023-10-01 12:15:00
# max                2023-12-31 23:00:00
# Name: dt, dtype: object

# %%
weather_2023_csv_data_df['Date_Time'].describe()
# Out:
# count                             1637
# mean     2023-10-01 08:45:09.089798144
# min                2023-09-01 00:51:00
# 25%                2023-09-17 00:51:00
# 50%                2023-09-30 06:51:00
# 75%                2023-10-16 07:51:00
# max                2023-10-31 23:51:00
# Name: Date_Time, dtype: object

# %%
weather_2024_xlsx_data_df['Date_Time'].describe()
# Out:
# count                          1000000
# mean     2024-03-10 10:40:58.896321792
# min                2024-01-01 00:00:06
# 25%      2024-02-04 16:28:23.750000128
# 50%                2024-03-10 11:43:28
# 75%         2024-04-14 03:51:32.500000
# max                2024-05-18 19:44:10
# Name: Date_Time, dtype: object

# %%
#nyc_weather_2016_2022_data_df
#nyc_weather_2023_xlsx_data_df

#weather_2023_csv_data_df
#weather_2024_xlsx_data_df

#weather_df_dic

# %%
weather_2024_xlsx_data_df['Date_Time'].describe()
# Out:
# count                          1000000
# mean     2024-03-10 10:40:58.896321792
# min                2024-01-01 00:00:06
# 25%      2024-02-04 16:28:23.750000128
# 50%                2024-03-10 11:43:28
# 75%         2024-04-14 03:51:32.500000
# max                2024-05-18 19:44:10
# Name: Date_Time, dtype: object

# %%
weather_2023_csv_data_df['Date_Time'].describe()
# Out:
# count                             1637
# mean     2023-10-01 08:45:09.089798144
# min                2023-09-01 00:51:00
# 25%                2023-09-17 00:51:00
# 50%                2023-09-30 06:51:00
# 75%                2023-10-16 07:51:00
# max                2023-10-31 23:51:00
# Name: Date_Time, dtype: object

# %%
nyc_weather_2023_xlsx_data_df['dt'].describe()
# Out:
# count                             9280
# mean     2023-07-02 15:36:42.672413696
# min                2023-01-01 00:00:00
# 25%                2023-04-01 16:45:00
# 50%                2023-07-02 22:30:00
# 75%                2023-10-01 12:15:00
# max                2023-12-31 23:00:00
# Name: dt, dtype: object

# %%
print(weather_2024_xlsx_data_df.columns)
print(weather_2023_csv_data_df.columns)
print(nyc_weather_2023_xlsx_data_df.columns)
# Out:
# Index(['Location', 'Date_Time', 'Temperature_C', 'Humidity_pct',
#        'Precipitation_mm', 'Wind_Speed_kmh'],
#       dtype='object')
# Index(['Month', 'Time', 'Temperature', 'Weather', 'Wind', 'Humidity',
#        'Visibility', 'Date_Time'],
#       dtype='object')
# Index(['dt', 'dt_iso', 'timezone', 'city_name', 'lat', 'lon', 'temp',
#        'visibility', 'dew_point', 'feels_like', 'temp_min', 'temp_max',
#        'pressure', 'sea_level', 'grnd_level', 'humidity', 'wind_speed',
#        'wind_deg', 'wind_gust', 'rain_1h', 'rain_3h', 'snow_3h', 'clouds_all',
#        'weather_id', 'weather_main', 'weather_description', 'weather_icon'],
#       dtype='object')

# %%
import matplotlib as mpl

# Set the path simplification threshold
mpl.rcParams['path.simplify_threshold'] = 1.0
# Set the chunk size for path simplification
mpl.rcParams['agg.path.chunksize'] = 10000


plt.figure(figsize=(12, 6))
plt.plot(weather_2024_xlsx_data_df['Date_Time'], weather_2024_xlsx_data_df['Temperature_C'])
plt.xlabel('Date_Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature over Time (2024)')
plt.grid(True)
plt.show()
